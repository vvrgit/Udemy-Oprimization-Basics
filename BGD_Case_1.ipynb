# %% [markdown]
# <a href="https://colab.research.google.com/github/vvrgit/Udemy-Oprimization-Basics/blob/main/BGD_Case_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random

# %%
data=pd.read_excel("/content/SampleData.xlsx")
data
# Out:
#      X    Y
# 0  0.2  3.4
# 1  0.4  3.8
# 2  0.6  4.2
# 3  0.8  4.6

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data.X, data.Y, test_size=0.2, random_state=42)

# %%
m=random.uniform(-10,10)
c=random.uniform(-10,10)
eta=0.1
epcohs=1000

# %%
for iter in range(epcohs):
  Gm=0
  Gc=0
  for sample in range(X_train.shape[0]):
    gm=-(y_train.iloc[sample]-m*X_train.iloc[sample]-c)*X_train.iloc[sample]
    gc=-(y_train.iloc[sample]-m*X_train.iloc[sample]-c)
    Gm=Gm+gm
    Gc=Gc+gc
  Gm=Gm/X_train.shape[0]
  Gc=Gc/X_train.shape[0]
  delm=-eta*Gm
  delc=-eta*Gc
  m=m+delm
  c=c+delc
print("m=",m)
print("c=",c)
# Out:
# m= 2.04635827282458
# c= 2.97403146019884

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
import random

# %%
data=pd.read_excel("/content/SampleData.xlsx")
data
# Out:
#      X    Y
# 0  0.2  3.4
# 1  0.4  3.8
# 2  0.6  4.2
# 3  0.8  4.6

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(data.X,data.Y,test_size=0.2,random_state=10)

# %%
Ns=X_train.shape[0]
print("Ns=",Ns)
# Out:
# Ns= 3

# %%
eta=0.9
epochs=1000
m=random.uniform(-1,1)
c=random.uniform(-1,1)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for iter in range(epochs):
  Gm=0
  Gc=0
  for sample in range(Ns):
    Gm=Gm+(y_train.iloc[sample]-m*X_train.iloc[sample]-c)*X_train.iloc[sample]
    Gc=Gc+(y_train.iloc[sample]-m*X_train.iloc[sample]-c)
  gm=-Gm/Ns
  gc=-Gc/Ns
  delm=-eta*gm
  delc=-eta*gc
  m=m+delm
  c=c+delc
print("model parameter m=",m)
print("model parameter c=",c)
# Out:
# model parameter m= 1.9999999999999958
# model parameter c= 3.0000000000000018

# %%
# Calculate predictions on the training data
y_train_pred = m * X_train + c

# Calculate the Mean Squared Error (MSE) on the training data
mse_train = ((y_train - y_train_pred) ** 2).mean()

print("Mean Squared Error on Training Data:", round(mse_train))
# Out:
# Mean Squared Error on Training Data: 0

# %%
# Calculate predictions on the testing data
y_test_pred = m * X_test + c

# Calculate the Mean Squared Error (MSE) on the training data
mse_test = ((y_test - y_test_pred) ** 2).mean()

print("Mean Squared Error on Testing Data:", round(mse_test))
# Out:
# Mean Squared Error on Testing Data: 0

# %%
x=input("enter x value")
m=2
c=3
yp=m*float(x)+c
print("Preidcted Value Yp=",yp)
# Out:
# enter x value0.2
# Preidcted Value Yp= 3.4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
import random

# %%
data=pd.read_excel("/content/Nitrogen.xlsx")
data.head()
# Out:
#    Pressure  Weight
# 0      75.1   577.8
# 1      74.3   577.0
# 2      88.7   570.9
# 3     114.6   578.6
# 4      98.5   572.4

# %%
data.describe()
# Out:
#          Pressure      Weight
# count   30.000000   30.000000
# mean    90.273333  514.963333
# std     16.986078   39.535096
# min     62.200000  406.700000
# 25%     75.300000  505.250000
# 50%     89.150000  510.100000
# 75%    104.375000  519.850000
# max    120.000000  578.600000

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the 'Pressure' and 'Weight' columns
data[['Pressure', 'Weight']] = scaler.fit_transform(data[['Pressure', 'Weight']])

print("Normalized Data:")
display(data.head())
# Out:
# Normalized Data:
#    Pressure    Weight
# 0  0.223183  0.995346
# 1  0.209343  0.990692
# 2  0.458478  0.955207
# 3  0.906574  1.000000
# 4  0.628028  0.963933

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(data.Pressure,data.Weight,test_size=0.1,random_state=42)

# %%
X_train
# Out:
# 17    0.271626
# 8     0.775087
# 9     0.489619
# 28    0.382353
# 24    1.000000
# 12    0.643599
# 0     0.223183
# 4     0.628028
# 16    0.069204
# 5     0.861592
# 13    0.532872
# 11    0.927336
# 22    0.200692
# 1     0.209343
# 2     0.458478
# 25    0.237024
# 3     0.906574
# 21    0.474048
# 26    0.242215
# 18    0.823529
# 29    0.619377
# 20    0.456747
# 7     0.000000
# 10    0.200692
# 14    0.202422
# 19    0.747405
# 6     0.910035
# Name: Pressure, dtype: float64

# %%
Ns=X_train.shape[0]
eta=0.0001
epochs=10000
m=random.uniform(-1,1)
c=random.uniform(-1,1)

# %%
for iter in range(epochs):
  Gm=0
  Gc=0
  for sample in range(Ns):
    Gm=Gm+(y_train.iloc[sample]-m*X_train.iloc[sample]-c)*X_train.iloc[sample]
    Gc=Gc+(y_train.iloc[sample]-m*X_train.iloc[sample]-c)
  gm=Gm/Ns
  gc=Gc/Ns
  delm=-eta*gm
  delc=-eta*gc
  m=m+delm
  c=c+delc
print("m=",m)
print("c=",c)
# Out:
# m= -0.8441225977471155
# c= 0.7179080552031335

# %%
# Calculate predictions on the training data
y_train_pred = m * X_train + c

# Calculate the Mean Squared Error (MSE) on the training data
mse_train = ((y_train - y_train_pred) ** 2).mean()

print("Mean Squared Error on Training Data:", mse_train)
# Out:
# Mean Squared Error on Training Data: 0.20346066446647415

# %%
# Calculate predictions on the training data
y_test_pred = m * X_test + c

# Calculate the Mean Squared Error (MSE) on the training data
mse_test = ((y_test - y_test_pred) ** 2).mean()

print("Mean Squared Error on Testing Data:", mse_test)
# Out:
# Mean Squared Error on Testing Data: 0.05433954819486845

# %%
Pressure=input("enter pressure value of liquid nitrogen")
Pressure=float(Pressure)
Pressure=(Pressure-62.2)/(120-62.2)
m=-0.8
c=0.7
Weight=m*Pressure+c
Weight=Weight*(578.6-406.7)+406.7
print(Weight)
# Out:
# enter pressure value of liquid nitrogen75.1
# 496.33782006920416

# %%
import numpy as np
import pandas as pd
import random

# %%
data=pd.read_excel("/content/Nitrogen.xlsx")
data.head()
# Out:
#    Pressure  Weight
# 0      75.1   577.8
# 1      74.3   577.0
# 2      88.7   570.9
# 3     114.6   578.6
# 4      98.5   572.4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
import random

# %%
data=pd.read_excel("/content/SampleData - MBGD.xlsx")
data.head()
# Out:
#      X    Y
# 0  0.1  3.2
# 1  0.2  3.4
# 2  0.3  3.6
# 3  0.4  3.8
# 4  0.5  4.0

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(data.X,data.Y,test_size=0.01,random_state=42)

# %%
# Out:
# 7    4.6
# Name: Y, dtype: float64

# %%
num_batches=2
X_train_batches = np.array_split(X_train, num_batches)
y_train_batches = np.array_split(y_train, num_batches)

print("Number of batches:", len(X_train_batches))
print("First batch of X_train:")
print(X_train_batches[0])
print("First batch of y_train:")
print(y_train_batches[0])
# Out:
# Number of batches: 2
# First batch of X_train:
# 1    0.2
# 5    0.6
# 0    0.1
# 8    0.9
# Name: X, dtype: float64
# First batch of y_train:
# 1    3.4
# 5    4.2
# 0    3.2
# 8    4.8
# Name: Y, dtype: float64
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)

# %%
print("Number of batches:", len(X_train_batches))
print("Second batch of X_train:")
print(X_train_batches[1])
print("Second batch of y_train:")
print(y_train_batches[1])
# Out:
# Number of batches: 2
# Second batch of X_train:
# 2    0.3
# 4    0.5
# 3    0.4
# 6    0.7
# Name: X, dtype: float64
# Second batch of y_train:
# 2    3.6
# 4    4.0
# 3    3.8
# 6    4.4
# Name: Y, dtype: float64

# %%
eta=0.0001
epochs=1000
m=random.uniform(-1,1)
c=random.uniform(-1,1)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for iter in range(epochs):
  for batch in range(num_batches):
    Gm=0
    Gc=0
    for sample in range(X_train_batches[batch].shape[0]):
      Gm=Gm-(y_train_batches[batch].iloc[sample]-m*X_train_batches[batch].iloc[sample]-c)*X_train_batches[batch]
      Gc=Gc-(y_train_batches[batch].iloc[sample]-m*X_train_batches[batch].iloc[sample]-c)
    gm=Gm/X_train_batches[batch].shape[0]
    gc=Gc/X_train_batches[batch].shape[0]
    delm=-eta*gm
    delc=-eta*gc
    m=m+delm
    c=c+delc
print("m=",m)
print("c=",c)
# Out:
# m= 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 8   NaN
# Name: X, dtype: float64
# c= 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 8   NaN
# Name: X, dtype: float64

# %%
# Out:
# 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
import random

# %%
data=pd.read_excel("/content/SampleData.xlsx")
data.head()
# Out:
#      X    Y
# 0  0.2  3.4
# 1  0.4  3.8
# 2  0.6  4.2
# 3  0.8  4.6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(data.X,data.Y,test_size=0.2,random_state=42)

# %%
Ns=X_train.shape[0]
eta=0.1
epochs=1000
m=random.uniform(-1,1)
c=random.uniform(-1,1)

# %%
for iter in range(epochs):
  Gm=0
  Gc=0
  for sample in range(Ns):
    Gm=Gm+(y_train.iloc[sample]-m*X_train.iloc[sample]-c)*X_train.iloc[sample]
    Gc=Gc+(y_train.iloc[sample]-m*X_train.iloc[sample]-c)
  gm=-Gm/Ns
  gc=-Gc/Ns
  delm=-eta*gm
  delc=-eta*gc
  m=m+delm
  c=c+delc
print("m=",round(m))
print("c=",round(c))
# Out:
# m= 2
# c= 3

# %%
y_train_pred=m*X_train+c
mse=((y_train-y_train_pred)**2).mean()
print("Mean Square Error with Training Data=",round(mse))
# Out:
# Mean Square Error with Training Data= 0

# %%
y_test_pred=m*X_test+c
mse=((y_test-y_test_pred)**2).mean()
print("Mean Square Error with Testing Data=",round(mse))
# Out:
# Mean Square Error with Testing Data= 0

# %%
X=input("enter input value")
X=float(X)
m=2
c=3
Y=m*X+c
print("Predicted Output Y = ", Y)
# Out:
# enter input value0.2
# Predicted Output Y =  3.4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
import random

# %%
data=pd.read_excel("/content/Nitrogen.xlsx")
data.head()
# Out:
#    Pressure  Weight
# 0      75.1   577.8
# 1      74.3   577.0
# 2      88.7   570.9
# 3     114.6   578.6
# 4      98.5   572.4

# %%
data.describe()
# Out:
#          Pressure      Weight
# count   30.000000   30.000000
# mean    90.273333  514.963333
# std     16.986078   39.535096
# min     62.200000  406.700000
# 25%     75.300000  505.250000
# 50%     89.150000  510.100000
# 75%    104.375000  519.850000
# max    120.000000  578.600000

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the 'Pressure' and 'Weight' columns
data[['Pressure', 'Weight']] = scaler.fit_transform(data[['Pressure', 'Weight']])

print("Normalized Data:")
display(data.head())
# Out:
# Normalized Data:
#    Pressure    Weight
# 0  0.223183  0.995346
# 1  0.209343  0.990692
# 2  0.458478  0.955207
# 3  0.906574  1.000000
# 4  0.628028  0.963933

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(data.Pressure,data.Weight,test_size=0.1,random_state=42)

# %%
Ns=X_train.shape[0]
eta=0.01
epochs=1000
m=random.uniform(-1,1)
c=random.uniform(-1,1)

# %%
for iter in range(epochs):
  Gm=0
  Gc=0
  for sample in range(Ns):
    Gm=Gm+(y_train.iloc[sample]-m*X_train.iloc[sample]-c)*X_train.iloc[sample]
    Gc=Gc+(y_train.iloc[sample]-m*X_train.iloc[sample]-c)
  gm=-Gm/Ns
  gc=-Gc/Ns
  delm=-eta*gm
  delc=-eta*gc
  m=m+delm
  c=c+delc
print("m=",m)
print("c=",c)
# Out:
# m= -0.24900936694843007
# c= 0.7635341769485993

# %%
y_train_pred=m*X_train+c
mse=((y_train-y_train_pred)**2).mean()
print("MSE-train=",mse)
# Out:
# MSE-train= 0.052719309814673744

# %%
y_test_pred=m*X_test+c
mse=((y_test-y_test_pred)**2).mean()
print("MSE-test=",mse)
# Out:
# MSE-test= 0.014491842352238013

# %%
Pressure=input("Enter Pressure of Nitorgen Gas")
Pressure=float(Pressure)
Pressure=(Pressure-62.2)/(120-62.2)
Weight=m*Pressure+c
Weight=Weight*(578.6-406.7)+406.7
print("Weight of Nitrogen Gas=",Weight)
# Out:
# Enter Pressure of Nitorgen Gas75.1
# Weight of Nitrogen Gas= 528.3982246489207

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
import random

# %%
data=pd.read_excel("/content/SampleData - MBGD.xlsx")
data
# Out:
#      X    Y
# 0  0.1  3.2
# 1  0.2  3.4
# 2  0.3  3.6
# 3  0.4  3.8
# 4  0.5  4.0
# 5  0.6  4.2
# 6  0.7  4.4
# 7  0.8  4.6
# 8  0.9  4.8

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(data.X,data.Y,test_size=0.1,random_state=42)
y_test
# Out:
# 7    4.6
# Name: Y, dtype: float64

# %%
num_batches=2
X_train_batches = np.array_split(X_train, num_batches)
y_train_batches = np.array_split(y_train, num_batches)

print("Number of batches:", len(X_train_batches))
print("First batch of X_train:")
print(X_train_batches[0])
print("First batch of y_train:")
print(y_train_batches[0])
# Out:
# Number of batches: 2
# First batch of X_train:
# 1    0.2
# 5    0.6
# 0    0.1
# 8    0.9
# Name: X, dtype: float64
# First batch of y_train:
# 1    3.4
# 5    4.2
# 0    3.2
# 8    4.8
# Name: Y, dtype: float64
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py:57: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)

# %%
print("Number of batches:", len(X_train_batches))
print("Second batch of X_train:")
print(X_train_batches[1])
print("Secons batch of y_train:")
print(y_train_batches[1])
# Out:
# Number of batches: 2
# Second batch of X_train:
# 2    0.3
# 4    0.5
# 3    0.4
# 6    0.7
# Name: X, dtype: float64
# Secons batch of y_train:
# 2    3.6
# 4    4.0
# 3    3.8
# 6    4.4
# Name: Y, dtype: float64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
eta=0.001
epochs=1000
m=random.uniform(-1,1)
c=random.uniform(-1,1)
nb=2
bs=X_train_batches[0].shape[0]

# %%
for iter in range(epochs):
  for batch in range(nb):
    Gm=0
    Gc=0
    for sample in range(bs):
      Gm=Gm+(y_train_batches[batch].iloc[sample]-m*X_train_batches[batch].iloc[sample]-c)*X_train_batches[batch].iloc[sample]
      Gc=Gc+(y_train_batches[batch].iloc[sample]-m*X_train_batches[batch].iloc[sample]-c)
    gm=-Gm/bs
    gc=-Gc/bs
    delm=-eta*gm
    delc=-eta*gc
    m=m+delm
    c=c+delc
print("m=",round(m))
print("c=",round(c))
# Out:
# m= 2
# c= 3

# %%
#Training MSE
y_train_pred=m*X_train+c
mse=((y_train-y_train_pred)**2).mean()
print("MSE_Train=",mse)
# Out:
# MSE_Train= 0.0027811198296192677

# %%
#Training MSE
y_test_pred=m*X_test+c
mse=((y_test-y_test_pred)**2).mean()
print("MSE_Test=",mse)
# Out:
# MSE_Test= 0.00756790064975925

# %%
X=input("Enter the value of X")
X=float(X)
m=2
c=3
Y=m*X+c
print("Predicted Output Y = ", Y)
# Out:
# Enter the value of X0.9
# Predicted Output Y =  4.8

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import random

# %%
data=pd.read_csv("/content/Housing.csv")
data.head()
# Out:
#       price  area
# 0  13300000  7420
# 1  12250000  8960
# 2  12250000  9960
# 3  12215000  7500
# 4  11410000  7420

# %%
price_min=data["price"].min()
price_max=data["price"].max()
area_min=data["area"].min()
area_max=data["area"].max()

# %%
data.describe()
# Out:
#               price          area
# count  5.450000e+02    545.000000
# mean   4.766729e+06   5150.541284
# std    1.870440e+06   2170.141023
# min    1.750000e+06   1650.000000
# 25%    3.430000e+06   3600.000000
# 50%    4.340000e+06   4600.000000
# 75%    5.740000e+06   6360.000000
# max    1.330000e+07  16200.000000

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the 'price' and 'area' columns
data[['price', 'area']] = scaler.fit_transform(data[['price', 'area']])

print("Normalized Data:")
display(data.head())
# Out:
# Normalized Data:
#       price      area
# 0  1.000000  0.396564
# 1  0.909091  0.502405
# 2  0.909091  0.571134
# 3  0.906061  0.402062
# 4  0.836364  0.396564

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data.area, data.price, test_size=0.2, random_state=42)

# %%
batch_size = 32 # Define your desired batch size
num_batches = X_train.shape[0] // batch_size
X_train_batches = np.array_split(X_train, num_batches)
y_train_batches = np.array_split(y_train, num_batches)

# %%
eta=0.01
epochs=1000
m=random.uniform(-1,1)
c=random.uniform(-1,1)

# %%
for iter in range(epochs):
  for batch in range(num_batches):
    Gm=0
    Gc=0
    for sample in range(X_train_batches[batch].shape[0]):
      Gm=Gm+(y_train_batches[batch].iloc[sample]-m*X_train_batches[batch].iloc[sample]-c)*X_train_batches[batch].iloc[sample]
      Gc=Gc+(y_train_batches[batch].iloc[sample]-m*X_train_batches[batch].iloc[sample]-c)
    gm=-Gm/X_train_batches[batch].shape[0]
    gc=-Gc/X_train_batches[batch].shape[0]
    delm=-eta*gm
    delc=-eta*gc
    m=m+delm
    c=c+delc
print("m=",m)
print("c=",c)
# Out:
# m= 0.5124751825067018
# c= 0.13305939510409043

# %%
#training MSE
y_train_pred=m*X_train+c
mse=((y_train-y_train_pred)**2).mean()
print("Training MSE:",mse)
# Out:
# Training MSE: 0.016540229591874556

# %%
#Testing MSE
y_test_pred=m*X_test+c
mse=((y_test-y_test_pred)**2).mean()
print("Testing MSE:",mse)
# Out:
# Testing MSE: 0.027776025601777322

# %%
Area=input("Enter Area of the house")
Area=float(Area)
Area=(Area-area_min)/(area_max-area_min)
m=0.5
c=0.1
Price=m*Area+c
Price=Price*(price_max-price_min)+price_min
print("House Price=",Price)
# Out:
# Enter Area of the house3000
# House Price= 3440824.7422680412

# %% [markdown]
# #Momentum Optimizer

# %%
import pandas as pd
import random

# %%
data=pd.read_excel("/content/SampleData.xlsx")
data
# Out:
#      X    Y
# 0  0.2  3.4
# 1  0.4  3.8
# 2  0.6  4.2
# 3  0.8  4.6

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(data.X,data.Y,test_size=0.2,random_state=42)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
eta=0.1
epochs=1000
m=random.uniform(-1,1)
c=random.uniform(-1,1)
Ns=X_train.shape[0]
gama=0.9
vm=0
vc=0

# %%
for iter in range(epochs):
  for sample in range(Ns):
    gm=-(y_train.iloc[sample]-m*X_train.iloc[sample]-c)*X_train.iloc[sample]
    gc=-(y_train.iloc[sample]-m*X_train.iloc[sample]-c)
    vm=gama*vm-eta*gm
    vc=gama*vc-eta*gc
    m=m+vm
    c=c+vc
print("m=",round(m))
print("c=",round(c))
# Out:
# m= 2
# c= 3

# %%
y_train_pred=m*X_train+c
mse=((y_train-y_train_pred)**2).mean()
print("Train_MSE=",round(mse))
# Out:
# Train_MSE= 0

# %%
y_test_pred=m*X_test+c
mse=((y_test-y_test_pred)**2).mean()
print("Test_MSE=",round(mse))
# Out:
# Test_MSE= 0

# %%
X=input("enter value of X")
X=float(X)
m=2
c=3
Y=m*X+c
print("Predicted Y = ",Y)
# Out:
# enter value of X0.6
# Predicted Y =  4.2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import random

# %%
data=pd.read_csv('/content/loaddata_simple_regression.csv')
data.head()
# Out:
#       L(T-24)        L(T)
# 0  5551.82208  4931.26380
# 1  4983.17184  4775.53968
# 2  4888.39680  4713.81120
# 3  5072.95872  4689.02628
# 4  5196.25980  4844.75040

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the 'L(T-24)' and 'L(T)' columns
data[['L(T-24)', 'L(T)']] = scaler.fit_transform(data[['L(T-24)', 'L(T)']])

print("Normalized Data:")
display(data.head())
# Out:
# Normalized Data:
#     L(T-24)      L(T)
# 0  0.397877  0.284300
# 1  0.293800  0.255799
# 2  0.276454  0.244501
# 3  0.310234  0.239965
# 4  0.332801  0.268466

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data[['L(T-24)']], data['L(T)'], test_size=0.2, random_state=42)

# %%
vm=0
vc=0
m=random.uniform(-1,1)
c=random.uniform(-1,1)
eta=0.1
epcohs=1
gama=0.9

# %%
for iter in range(epochs):
  for sample in range(X_train.shape[0]):
    gm=-(y_train.iloc[sample]-m*X_train.iloc[sample]-c)*X_train.iloc[sample]
    gc=-(y_train.iloc[sample]-m*X_train.iloc[sample]-c)
    vm=gama*vm-eta*gm
    vc=gama*vc-eta*gc
    m=m+vm
    c=c+vc
print("m=",m)
print("c=",c)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2494014937.py in <cell line: 0>()
#       1 for iter in range(epochs):
#       2   for sample in range(X_train.shape[0]):
# ----> 3     gm=-(y_train.iloc[sample]-m*X_train.iloc[sample]-c)*X_train.iloc[sample]
#       4     gc=-(y_train.iloc[sample]-m*X_train.iloc[sample]-c)
#       5     vm=gama*vm-eta*gm
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/arraylike.py in __sub__(self, other)
#     192     @unpack_zerodim_and_defer("__sub__")
#     193     def __sub__(self, other):
# --> 194         return self._arith_method(other, operator.sub)
#     195
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import random

# %%
data=pd.read_excel("/content/SampleData.xlsx")
data
# Out:
#      X    Y
# 0  0.2  3.4
# 1  0.4  3.8
# 2  0.6  4.2
# 3  0.8  4.6

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data.X,data.Y,test_size=0.2, random_state=42)

# %%
Ns=X_train.shape[0]
gama=0.9
eta=0.1
epochs=1000
vm=0
vc=0
m=random.uniform(-1,1)
c=random.uniform(-1,1)

# %%
for iter in range(epochs):
  for sample in range(Ns):
    gm=-(y_train.iloc[sample]-(m+gama*vm)*X_train.iloc[sample]-(c+gama*vc))*X_train.iloc[sample]
    gc=-(y_train.iloc[sample]-(m+gama*vm)*X_train.iloc[sample]-(c+gama*vc))
    vm=gama*vm-eta*gm
    vc=gama*vc-eta*gc
    m=m+vm
    c=c+vc
print("m=",round(m))
print("c=",round(c))
# Out:
# m= 2
# c= 3

# %%
#training MSE
y_train_pred=m*X_train+c
mse=((y_train-y_train_pred)**2).mean()
print("Training MSE=",round(mse))
# Out:
# Training MSE= 0

# %%
#Testing MSE
y_test_pred=m*X_test+c
mse=((y_test-y_test_pred)**2).mean()
print("Testing MSE=",round(mse))
# Out:
# Testing MSE= 0

# %%
X=input("Enter X value")
X=float(X)
m=2
c=3
Y=m*X+c
print("Y=",Y)
# Out:
# Enter X value0.8
# Y= 4.6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import random
import pandas as pd

# %%
data=pd.read_csv('/content/loaddata_simple_regression.csv')
data.head()
# Out:
#       L(T-24)        L(T)
# 0  5551.82208  4931.26380
# 1  4983.17184  4775.53968
# 2  4888.39680  4713.81120
# 3  5072.95872  4689.02628
# 4  5196.25980  4844.75040

# %%
ip_min=data["L(T-24)"].min()
ip_max=data["L(T-24)"].max()
op_min=data["L(T)"].min()
op_max=data["L(T)"].max()

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the 'L(T-24)' and 'L(T)' columns
data[['L(T-24)', 'L(T)']] = scaler.fit_transform(data[['L(T-24)', 'L(T)']])

print("Normalized Data:")
display(data.head())
# Out:
# Normalized Data:
#     L(T-24)      L(T)
# 0  0.246011  0.069070
# 1  0.083870  0.024668
# 2  0.056847  0.007067
# 3  0.109472  0.000000
# 4  0.144629  0.044402

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data[['L(T-24)']], data['L(T)'], test_size=0.2, random_state=42)

# %%
Ns=X_train.shape[0]
gama=0.9
eta=0.1
epcohs=100
m=random.uniform(-1,1)
c=random.uniform(-1,1)
vm=0
vc=0

# %%
for iter in range(epochs):
  for sample in range(Ns):
    gm=-(y_train.iloc[sample]-(m+gama*vm)*X_train.iloc[sample]-(c+gama*vc))*X_train.iloc[sample]
    gc=-(y_train.iloc[sample]-(m+gama*vm)*X_train.iloc[sample]-(c+gama*vc))
    vm=gama*vm-eta*gm
    vc=gama*vc-eta*gc
    m=m+vm
    c=c+vc
print("m=",round(m))
print("c=",round(c))
# Out:
# m= L(T-24)    1.0
# dtype: float64
# c= L(T-24)   -0.0
# dtype: float64

# %%
print("m=",m)
print("c=",c)
# Out:
# m= L(T-24)    0.691628
# dtype: float64
# c= L(T-24)   -0.058305
# dtype: float64

# %%
#training MSE
y_train_pred=m*X_train+c
mse=((y_train-y_train_pred)**2).mean()
print("Training MSE=",round(mse))
# Out:
# Training MSE= 1         NaN
# 2         NaN
# 3         NaN
# 5         NaN
# 6         NaN
#            ..
# 96        NaN
# 97        NaN
# 98        NaN
# 99        NaN
# L(T-24)   NaN
# Length: 81, dtype: float64
